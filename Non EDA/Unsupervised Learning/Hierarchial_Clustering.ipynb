# %% [markdown]
# ### **Hierarchial Clustering**

# %% [markdown]
# * Hierarchical clustering is another unsupervised machine learning algorithm, which is used to group the unlabeled datasets into a cluster and also known as hierarchical cluster analysis or HCA.
# * In this algorithm, we develop the hierarchy of clusters in the form of a tree, and this tree-shaped structure is known as the dendrogram.Sometimes the results of K-means clustering and hierarchical clustering may look similar, but they both differ depending on how they work. As there is no requirement to predetermine the number of clusters as we did in the K-Means algorithm.
# * It has 2 types of approches :-
# * Agglomerative: Agglomerative is a bottom-up approach, in which the algorithm starts with taking all data points as single clusters and merging them until one cluster is left.
# * Divisive: Divisive algorithm is the reverse of the agglomerative algorithm as it is a top-down approach.

# %% [markdown]
# **Step 1 : Import Necessary libraries**

# %% [markdown]
# * Import libraries for our model, which is a part of data pre-processing.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# **Step 2 : Import the dataset**

# %% [markdown]
# * Import the dataset that we need to use. Here, the dataset we are using is "Mall_Customers_data.csv dataset.

# %%
df = pd.read_csv("E:\\Machine Learning\\Datasets\\Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# **Step 3 : Extracting the target variables**

# %% [markdown]
# * As we can see the we extracted the third and fourth feature it is because we need a 2-D plot to visualize the model and some features are not requires , suchas customer_ID.

# %%
x = df.iloc[:, [3,4]].values

# %% [markdown]
# **Step 4 : Hierarchical Clustering Dendrogram Plot**

# %% [markdown]
# * This code snippet is used to generate a dendrogram, which is a tree-like diagram that illustrates the hierarchical relationships between data points in a dataset. The dendrogram helps visualize how clusters are formed at different levels of hierarchy.
# * The dendrogram is used to determine the optimal number of clusters for hierarchical clustering.
# * By examining the vertical distances (linkages), users can decide where to "cut" the tree to define clusters.

# %%
plt.figure(figsize=(15, 10))
dendro = shc.dendrogram(shc.linkage(x, method='ward'))
plt.title("Dendrogram Plot")
plt.xlabel("Customers")
plt.ylabel("Euclidean Distances")
plt.show()

# %% [markdown]
# * The below code is used to perform agglomerative clustering by using euclidean metrics and method used is Ward's method.
# * Ward's method minimizes the variance within clusters and merges clusters that lead to the least increase in total intra-cluster variance.

# %%
from sklearn.cluster import AgglomerativeClustering 
hc = AgglomerativeClustering(n_clusters = 5, metric = "euclidean", linkage = 'ward')
y_pred = hc.fit_predict(x)

# %%
plt.scatter(x[y_pred == 0,0],x[y_pred == 0,1], s = 100, c = 'blue', label = 'Cluster1')
plt.scatter(x[y_pred == 1,0],x[y_pred == 1,1], s = 100, c = 'green', label = 'Cluster2')
plt.scatter(x[y_pred == 2,0],x[y_pred == 2,1], s = 100, c = 'orange', label = 'Cluster3')
plt.scatter(x[y_pred == 3,0],x[y_pred == 3,1], s = 100, c = 'pink', label = 'Cluster4')
plt.scatter(x[y_pred == 4,0],x[y_pred == 4,1], s = 100, c = 'brown', label = 'Cluster5')
plt.title("Clusters of Customers")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.legend()
plt.show()
